# %% [markdown]
# <h1 style="text-align:center"> Drexel University </h1>
# <h2 style = "text-align:center"> College of Computing and Informatics</h2>
# <h2 style = "text-align:center">INFO 212: Data Science Programming I</h2>
# <h3 style = "text-align:center">Assignment 2</h3>
# <div style="text-align:center; border-style:solid; padding: 10px">
# <div style="font-weight:bold">Due Date: Sunday, April 29, 2018</div>
# This assignment counts for 10% of the final grade
# </div>
#
# <h3 style="color:red; font-weight:bold; text-decoration: underline">DON'T FORGET TO PUT YOUR NAME BELOW</h3>
#
# ### NAME: Raj B. Patel
#
#
# ### A. Assignment Overview
# This assignment provides the opportunity for you to practice with the capabilities in Python Numpy and Pandas.
#
# ### B. What to Hand In
#
# Sumbit a completed this Jupyter notebook.
#
# ### C. How to Hand In
#
# Submit your Jupyter notebook file through the course website in the Blackboard Learn system.
#
# ### D. When to Hand In
#
# 1. Submit your assignment no later than 11:59pm in the due date.
# 2. There will be a 10% (absolute value) deduction for each day of lateness, to a maximum of 3 days; assignments will not be accepted beyond that point. Missing work will earn a zero grade.
#
# ### E. Written Presentation Requirements (if applicable)
# Images must be clear and legible. Assignments will be judged on the basis of visual appearance, grammatical correctness, and quality of writing, as well as their contents. Please make sure that the text of your assignments is well-structured, using paragraphs, full sentences, and other features of well-written presentation. Text font size should be either 11 or 12 points.
#
# ### F. Marking Schemes:
#
# Marking assignments will be based on several aspects: presentation, correctness and coding styles.
#
# For programming questions, 10% of the mark will be judged on the coding style.
#
# The following is a set of guidelines for the coding style in this course:
# 1. Write a good comment for each variable, each method, each control branch, and each loop.
# 2. Use appropriate indentations to indicate control flows and blocks of code.
# 3. Your method comments must mention the purpose of each parameter, and must be grammatically correct.
# 4. Each line must be less than 80 characters long including tabs and spaces.
# 5. Put a blank space before and after every operator.
# 6. When breaking up a long line, break it before an operator, not after.
#
# ### G. Data Sets
#
# This assignment needs the data sets posted in the Week 3 module. Follow the instructions inside Week 3 module to download and unpack the "Inflammation-data" and "Wine Reviews" data sets.
#
# ### H. Answer the following questions

# %% [markdown]
# #### Question 1:
# Write a program to list all the inflammation csv files in the 'inflammation-data' directory and count the number of such files. An inflammation csv file has a name containing 'inflammation' and with extension '.csv'.

# %%
# import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from os import listdir

#Define a function to list all the inflammation csv files and their count
def fileInfo(path):
    #create a variable to store all file names in the given path
    filenames = listdir("../DataSets/inflammation-data")
    #create a variable to store the output of a loop that returns 
    #filenames ending with .csv containing the name "inflammation"
    files =  [filename for filename in filenames if filename.endswith(".csv")
      and "inflammation" in filename]
    #return the list of filenames and the count of those files 
    print(files) 
    print(len(files))

fileInfo("../DataSets/inflammation-data")
# Out:
# ['inflammation-05.csv', 'inflammation-11.csv', 'inflammation-10.csv', 'inflammation-04.csv', 'inflammation-12.csv', 'inflammation-06.csv', 'inflammation-07.csv', 'inflammation-03.csv', 'inflammation-02.csv', 'inflammation-01.csv', 'inflammation-09.csv', 'inflammation-08.csv']
# 12

# %% [markdown]
# ***
# # Question 1 Solution:
# 1) The csv files in the 'inflammation-data' directory with a name containing 'inflammation' and extension '.csv' are in this list:
# ['inflammation-05.csv', 'inflammation-11.csv', 'inflammation-10.csv', 'inflammation-04.csv', 'inflammation-12.csv', 'inflammation-06.csv', 'inflammation-07.csv', 'inflammation-03.csv', 'inflammation-02.csv', 'inflammation-01.csv', 'inflammation-09.csv', 'inflammation-08.csv']
#
# The number of such files is 12.
#
# ***

# %% [markdown]
# #### Question 2:
# Load the data in the file 'inflammation-05.csv' to an Numpy array. Answer the following questions:
# * Suppose the rows represent patients, and columns represent days. How many patients and how many days does the file contain inflammation data for?
# * Extract the values for the last 10 patients' inflammation in last 10 days.
# * Compute an array containing the average inflammation for all patients across all days. Plot the averages and label the plot with "Average Inflammation of Patients".
# * Compute an array containing the average inflammtion for all days across all patients. Plot the averages and label the plot with "Average Inflammation of Days"

# %%
#load the comma separated data from the text file in variable data
data = np.loadtxt("../DataSets/inflammation-data/inflammation-05.csv",
                  delimiter = ",")
#create a variable to store the shape of the array held in data
shape = data.shape
print("There are {0} patients and {1} days' worth of data".
      format(shape[0], shape[1]))

#Create a variable to hold values for the last
#10 patients' inflammation in last 10 days.
lastTen = data[-10:, -10:]
print(lastTen)


#create a variable to hold the the average inflammation
#for all patients across all days
average = np.mean(data, axis = 1)

#set up the field to hold the graphs
fig = plt.figure(figsize=(10,5))

#set up the graph positioning
axes1 = fig.add_subplot(1,2,1) 
#plot title
axes1.set_title("Average Inflammation of Patients")
#plot the means of all patients
axes1.plot(average)

#create a variable to hold the the average inflammation
#for all days across all patients
average = np.mean(data, axis = 0)

#set up the graph positioning
axes1 = fig.add_subplot(1,2,2)
#plot title
axes1.set_title("Average Inflammation of Days")
#plot the means of all days
axes1.plot(np.mean(data, axis = 0))
# Out:
# There are 60 patients and 40 days' worth of data
# [[5. 2. 8. 4. 2. 4. 2. 0. 1. 0.]
#  [6. 7. 8. 1. 4. 4. 1. 0. 2. 0.]
#  [5. 7. 6. 6. 4. 3. 4. 0. 1. 0.]
#  [8. 9. 6. 6. 6. 3. 3. 1. 1. 0.]
#  [7. 7. 4. 5. 6. 4. 4. 0. 1. 1.]
#  [6. 9. 6. 3. 4. 5. 3. 2. 0. 0.]
#  [6. 7. 4. 2. 1. 4. 2. 1. 0. 1.]
#  [2. 5. 7. 6. 1. 5. 4. 0. 1. 1.]
#  [2. 6. 6. 3. 2. 5. 4. 1. 2. 1.]
#  [6. 9. 5. 3. 3. 2. 4. 1. 0. 1.]]

# %% [markdown]
# # Question 2 Solution
# 1) The 'inflammation-05.csv'contains inflammation data for 60 patients and 40 days.
#
# 2) The values for the last 10 patients' inflammation in the last 10 days include:
# [[5. 2. 8. 4. 2. 4. 2. 0. 1. 0.]
#  [6. 7. 8. 1. 4. 4. 1. 0. 2. 0.]
#  [5. 7. 6. 6. 4. 3. 4. 0. 1. 0.]
#  [8. 9. 6. 6. 6. 3. 3. 1. 1. 0.]
#  [7. 7. 4. 5. 6. 4. 4. 0. 1. 1.]
#  [6. 9. 6. 3. 4. 5. 3. 2. 0. 0.]
#  [6. 7. 4. 2. 1. 4. 2. 1. 0. 1.]
#  [2. 5. 7. 6. 1. 5. 4. 0. 1. 1.]
#  [2. 6. 6. 3. 2. 5. 4. 1. 2. 1.]
#  [6. 9. 5. 3. 3. 2. 4. 1. 0. 1.]]
#
# 3) Plot of Average Inflammation of Patients:
# <img src="byPatient.png", width = 285, height = 250>
#
#
# 4) Plot of Average Inflammation of Days:
# <img src="byDay.png", width = 300, height = 250>

# %% [markdown]
# #### Qestion 3:
# Given the following list of file names:
# ```
# filenames = ['inflammation-02.csv', 'inflammation-04.csv', 'inflammation-06.csv']
# ```
# Write a program to plot the daily averages, maximums, and minimums of inflammation for each of the file. Your plot should have three rows each of which shows side-by-side plots of average, max, and min. The following figure illustrates the expected outcome:
# ![](assignment2-question3.png)

# %%
# function to plot mean, max, and min data for three input files
def plotFiles(file1, file2, file3):
    #load the data files into variables
    file1 = np.loadtxt("../DataSets/inflammation-data/inflammation-02.csv",
                       delimiter = ",")
    file2 = np.loadtxt("../DataSets/inflammation-data/inflammation-04.csv",
                       delimiter = ",")
    file3 = np.loadtxt("../DataSets/inflammation-data/inflammation-06.csv",
                       delimiter = ",")
    #an array to hold the file names
    names = ["Inflammation-02.csv", "Inflammation-04.csv",
             "Inflammation-06.csv"]
    
    #an array to hold the loaded data files
    all_files = [file1, file2, file3]
    
    #loop through each file  
    for i in range(0,3,1):
        #compute arrays to hold calculated values 
        a = np.mean(all_files[i], axis = 0)
        b = np.max(all_files[i], axis = 0)
        c = np.min(all_files[i], axis = 0)
        
        #set up the plot
        layout = plt.figure(figsize=(20,12))
        #display the filenames
        plt.suptitle(names[i], fontsize = 14)
        
        #add subplots for mean, max, and min plots
        axes1 = layout.add_subplot(331) 
        axes2 = layout.add_subplot(332) 
        axes3 = layout.add_subplot(333)
        
        #plot the charts and set the labels
        axes1.plot(a) 
        axes1.set_ylabel("Average", fontsize = 12)
        axes2.plot(b) 
        axes2.set_ylabel("Maximum", fontsize = 12)
        axes3.plot(c) 
        axes3.set_ylabel("Minimum", fontsize = 12)
        
        #configure the space
        plt.subplots_adjust(left=0.2, wspace=0.25, top=0.95)
plotFiles("../DataSets/inflammation-data/inflammation-02.csv", "../DataSets/inflammation-data/inflammation-04.csv", "../DataSets/inflammation-data/inflammation-06.csv")

# %% [markdown]
# # Question 3 Solution
#
# 1) Here is a plot of the daily averages, maximums, and minimums of inflammation for each of the files:
#
# <img src = "plots.png", height = 1000, width = 1000>

# %% [markdown]
# #### Question 4:
# Download the data file "winemag-data-130k-v2.csv" and load it into a Pandas DataFrame using the column 0 as index. This data set contains 130k reviews for different wine verieties. Answer the following questions:
# * What features do the reviews use?
# * What is the description for the third view?
# * Select the country, province, region_1, and region_2 columns of the records with the 0, 1, 10, and 100 index positions.
# * Select all the reviews for wines made in 'Italy'. How many reviews are there for wines made in 'Italy'?
# * Suppose the 'points' column represents the rating of a wine. An above-averagely good wine has a value in 'points' equal or greater than 90. Between France and Italy, which country has more reviews for its above-averagely good wines?

# %%
#create a variable to hold the wine review data
wineData = pd.read_csv("../DataSets/winemag-data-130k-v2.csv", index_col = 0)

#create a variable to hold the column names
features = wineData.columns
print(features)

# return the description for the third view
description = wineData.iloc[2]["description"]
print(description)

#Select the country, province, region_1, and region_2 columns
#of the records with the 0, 1, 10, and 100 index positions.

selection = wineData.loc[[0, 1, 10, 100], 
             ['country', 'province', "region_1", "region_2"]]
print(selection)

#Select all the reviews for wines made in 'Italy'. 
#find how many reviews are there for wines made in 'Italy'
Italy = wineData[wineData['country'] == "Italy"]
print("There are ",Italy.shape[0]," reviews for wines made in Italy.")

#Find which country between France and Italy that produces
#more above-averagely good wines?

#create variables that hold country specific data
France = wineData['country'] == "France" 
Italy = wineData['country'] == "Italy" 

# Create variable holding instances when points are greater or equal to 90
criteria = wineData['points'] >= 90

# Select all cases where nationality is USA and age is greater than 50
combined = wineData[(France | Italy ) & criteria]

#separate the data from France and Italy
f = combined["country"] == "France"
i = combined["country"] == "Italy"

#print out results
print(("Italy has {0} above-averagely good wines reviews.".format(sum(i))),
      ("France has {0} above-averagely good wines reveiws.".format(sum(f))))
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')
# Tart and snappy, the flavors of lime flesh and rind dominate. Some green pineapple pokes through, with crisp acidity underscoring the flavors. The wine was all stainless-steel fermented.
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes
# There are  19540  reviews for wines made in Italy.
# Italy has 6648 above-averagely good wines reviews. France has 9192 above-averagely good wines reveiws.

# %% [markdown]
# # Question 4 Solution:
# 1) The reviews use the following features:
# ['country', 'description', 'designation', 'points', 'price', 'province', 'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title', 'variety', 'winery']
#
# 2) The description value for the third review is: 'Tart and snappy, the flavors of lime flesh and rind dominate. Some green pineapple pokes through, with crisp acidity underscoring the flavors. The wine was all stainless-steel fermented.'
#
# 3) The selection of country, province, region_1, and region_2 columns of the records with the 0, 1, 10, and 100 index positions:
# <img src = "selection.png", height =350, width = 400>
#
# 4) Please see the selction of wines made in "Italy" above. There are 19,540 reviews for wines made in Italy.
#
# 5) Between France and Italy, France produces more above-averagely good wines.

# %% [markdown]
# #### Question 5:
# Continue to work on the DataFrame of wine review loaded in Question 4. Answer the following questions:
# * What countries are represented in the data set?
# * What top 10 countries most frequently appear in the dataset?
# * What is the median of the price?
# * Create a new column 'price_norm' by subtracting the median price from the price column. Use the DataFrame.apply method.
# * Create a new column 'bargain' which contains the points-to-price ratio. Which wine is the "best bargain", e.g., which wine has the highest points-to-price ratio in the dataset?

# %%
#array to hold all unique countries
all_countries = set(np.array(wineData['country']))
print(all_countries)


#Find the top 10 countries which produce the most reviews
topTen = (wineData.country.value_counts().head(10))
print(topTen.index)


#finds the median of the price vector 
price_median = wineData["price"].median(skipna=True)
print(price_median)

#create a new column "price_norm that holds price - median
norm = lambda x: wineData.price - price_median
wineData["price_Norm"] = wineData.apply(norm, axis = 0)

#create a new column 'bargain'that holds the points-to-price ratio
wineData["bargain"] = wineData.points / wineData.price
#find the best bargain
bestBargain = np.amax(wineData["bargain"])
location = wineData.loc[wineData["bargain"] == 21.5]
wineNames = location.title
print(wineNames)
# Out:
# {nan, 'Romania', 'Croatia', 'Uruguay', 'China', 'US', 'Argentina', 'Spain', 'Switzerland', 'Egypt', 'Israel', 'Armenia', 'Lebanon', 'India', 'New Zealand', 'Macedonia', 'Brazil', 'Ukraine', 'South Africa', 'Chile', 'Cyprus', 'Luxembourg', 'Slovakia', 'Canada', 'England', 'Italy', 'Portugal', 'Georgia', 'Slovenia', 'Bulgaria', 'Germany', 'Australia', 'Greece', 'Mexico', 'Morocco', 'Serbia', 'France', 'Hungary', 'Peru', 'Austria', 'Bosnia and Herzegovina', 'Turkey', 'Czech Republic', 'Moldova'}
# Index(['US', 'France', 'Italy', 'Spain', 'Portugal', 'Chile', 'Argentina',
#        'Austria', 'Australia', 'Germany'],
#       dtype='object')
# 25.0
# 64590                         Bandit NV Merlot (California)
# 126096    Cramele Recas 2011 UnWineD Pinot Grigio (Viile...
# Name: title, dtype: object

# %% [markdown]
# # Question 5 Solution:
#
# 1) The countries represented in the data set include: 'Argentina', 'Armenia', 'Australia', 'Austria', 'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'China', 'Croatia', 'Cyprus', 'Czech Republic', 'Egypt', 'England', 'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'India', 'Israel', 'Italy', 'Lebanon', 'Luxembourg', 'Macedonia', 'Mexico', 'Moldova', 'Morocco', 'New Zealand', 'Peru', 'Portugal', 'Romania', 'Serbia', 'Slovakia', 'Slovenia', 'South Africa', 'Spain', 'Switzerland', 'Turkey', 'US', 'Ukraine', 'Uruguay'
#
# 2) The top 10 countries that appears the most often are: ['US', 'France', 'Italy', 'Spain', 'Portugal', 'Chile', 'Argentina', 'Austria', 'Australia', 'Germany']
#
# 3) The median of the price is 25.0
#
# 4) See code above
#
# 5) The wines that have the highest points-to-price ratio in the dataset include:
#     - Bandit NV Merlot (California)
#     - Cramele Recas 2011 UnWineD Pinot Grigio (Viile Timisului)
